# %% [markdown]
# <a href="https://colab.research.google.com/github/Al-ameen007/CIFAR_10/blob/main/MNIST_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing the data and some preprocessing

# %%
import numpy as np
from matplotlib import pyplot as plt
import tensorflow
from tensorflow import keras

# %%
from tensorflow.keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
# Normalizing the data and one-hot encoding the labels
from tensorflow.keras.utils import to_categorical
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# Splitting the data into training and validation sets as we want to save the test set for the evaluation of the best model
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, random_state=42)

# %%
from keras import models
from keras import layers
from tensorflow.keras import optimizers

# %%
saved_models = []
accuracies = []

# %% [markdown]
# #Base Model

# %%
model = models.Sequential()
model.add(layers.Conv2D(64, (5, 5), strides=(2, 2),activation='relu', kernel_initializer='truncated_normal', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu', kernel_initializer='he_uniform'))
model.add(layers.Dense(10, activation='softmax'))

# %%
opt = optimizers.SGD(learning_rate=0.0001, momentum=0.9)
opt_1 = optimizers.SGD(learning_rate=0.05, momentum=0.9)
opt_2 = optimizers.SGD(learning_rate=0.001, momentum=0.9)
opt_3 = optimizers.SGD(learning_rate=0.01, momentum=0.9)
opt_4 = optimizers.Adam(learning_rate=0.01, beta_1=0.9, beta_2=0.999)
opt_5 = optimizers.RMSprop(learning_rate=0.01, rho=0.9, momentum=0.1,)

# %%
def evaluate_model(saved_models, X, y):
  best_model, best_model_idx = saved_models[0], 0
  best_accuracy= (best_model.evaluate(X, y, verbose=1))[1]
  for i in range(1, len(saved_models)):
    loss, acc = saved_models[i].evaluate(X, y, verbose=1)
    if acc > best_accuracy:
      best_model, best_model_idx , best_accuracy= saved_models[i], i, acc
  print('model: ' + str(best_model_idx + 1), 'accuracy: ' + str('%.2f'%(best_accuracy * 100) + ' %'))
  return best_model, acc

# %%
def summaries(saved_models):
  for model in range(0, len(saved_models)):
    print('model: ' + str(i + 1))
    saved_models[i].summary()

# %% [markdown]
# #Trying differnt number of epochs

# %%
model_1 = keras.models.clone_model(model)
model_1.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_1.fit(X_train, y_train, epochs=10, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_1)
# Out:
# Epoch 1/10
# 1594/1594 [==============================] - 17s 10ms/step - loss: 2.1238 - accuracy: 0.4680 - val_loss: 1.8192 - val_accuracy: 0.6690
# Epoch 2/10
# 1594/1594 [==============================] - 15s 10ms/step - loss: 1.3099 - accuracy: 0.7364 - val_loss: 0.8879 - val_accuracy: 0.7959
# Epoch 3/10
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.6962 - accuracy: 0.8307 - val_loss: 0.5706 - val_accuracy: 0.8528
# Epoch 4/10
# 1594/1594 [==============================] - 17s 10ms/step - loss: 0.5063 - accuracy: 0.8652 - val_loss: 0.4565 - val_accuracy: 0.8734
# Epoch 5/10
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.4278 - accuracy: 0.8817 - val_loss: 0.3988 - val_accuracy: 0.8867
# Epoch 6/10
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.3846 - accuracy: 0.8911 - val_loss: 0.3638 - val_accuracy: 0.8971
# Epoch 7/10
# 1594/1594 [==============================] - 17s 11ms/step - loss: 0.3560 - accuracy: 0.8982 - val_loss: 0.3401 - val_accuracy: 0.9059
# Epoch 8/10
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.3345 - accuracy: 0.9039 - val_loss: 0.3197 - val_accuracy: 0.9092
# Epoch 9/10
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.3172 - accuracy: 0.9080 - val_loss: 0.3039 - val_accuracy: 0.9130
# Epoch 10/10
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.3027 - accuracy: 0.9117 - val_loss: 0.2913 - val_accuracy: 0.9151

# %%
model_2 = keras.models.clone_model(model)
model_2.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_2.fit(X_train, y_train, epochs=15, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_2)
# Out:
# Epoch 1/15
# 1594/1594 [==============================] - 17s 10ms/step - loss: 2.1172 - accuracy: 0.4352 - val_loss: 1.8053 - val_accuracy: 0.6509
# Epoch 2/15
# 1594/1594 [==============================] - 16s 10ms/step - loss: 1.2758 - accuracy: 0.7445 - val_loss: 0.8575 - val_accuracy: 0.8011
# Epoch 3/15
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.6732 - accuracy: 0.8325 - val_loss: 0.5579 - val_accuracy: 0.8514
# Epoch 4/15
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.4953 - accuracy: 0.8664 - val_loss: 0.4501 - val_accuracy: 0.8776
# Epoch 5/15
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.4190 - accuracy: 0.8834 - val_loss: 0.3917 - val_accuracy: 0.8917
# Epoch 6/15
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.3750 - accuracy: 0.8951 - val_loss: 0.3568 - val_accuracy: 0.9013
# Epoch 7/15
# 1594/1594 [==============================] - 17s 10ms/step - loss: 0.3460 - accuracy: 0.9022 - val_loss: 0.3309 - val_accuracy: 0.9052
# Epoch 8/15
# 1594/1594 [==============================] - 17s 10ms/step - loss: 0.3244 - accuracy: 0.9070 - val_loss: 0.3107 - val_accuracy: 0.9121
# Epoch 9/15
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.3073 - accuracy: 0.9121 - val_loss: 0.2950 - val_accuracy: 0.9166
# Epoch 10/15
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.2933 - accuracy: 0.9161 - val_loss: 0.2817 - val_accuracy: 0.9193
# Epoch 11/15
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.2806 - accuracy: 0.9191 - val_loss: 0.2698 - val_accuracy: 0.9231
# Epoch 12/15
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.2695 - accuracy: 0.9222 - val_loss: 0.2589 - val_accuracy: 0.9266
# Epoch 13/15
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.2594 - accuracy: 0.9248 - val_loss: 0.2497 - val_accuracy: 0.9271
# Epoch 14/15
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.2498 - accuracy: 0.9275 - val_loss: 0.2405 - val_accuracy: 0.9316
# Epoch 15/15
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.2413 - accuracy: 0.9301 - val_loss: 0.2324 - val_accuracy: 0.9342

# %%
model_3 = keras.models.clone_model(model)
model_3.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_3.fit(X_train, y_train, epochs=20, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_3)
# Out:
# Epoch 1/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 2.1110 - accuracy: 0.4280 - val_loss: 1.7785 - val_accuracy: 0.6559
# Epoch 2/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 1.2362 - accuracy: 0.7510 - val_loss: 0.8248 - val_accuracy: 0.8037
# Epoch 3/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.6521 - accuracy: 0.8386 - val_loss: 0.5424 - val_accuracy: 0.8583
# Epoch 4/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.4840 - accuracy: 0.8719 - val_loss: 0.4395 - val_accuracy: 0.8818
# Epoch 5/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.4115 - accuracy: 0.8872 - val_loss: 0.3860 - val_accuracy: 0.8986
# Epoch 6/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.3693 - accuracy: 0.8977 - val_loss: 0.3486 - val_accuracy: 0.9033
# Epoch 7/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.3407 - accuracy: 0.9047 - val_loss: 0.3234 - val_accuracy: 0.9112
# Epoch 8/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.3190 - accuracy: 0.9096 - val_loss: 0.3035 - val_accuracy: 0.9156
# Epoch 9/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.3014 - accuracy: 0.9143 - val_loss: 0.2887 - val_accuracy: 0.9189
# Epoch 10/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.2868 - accuracy: 0.9181 - val_loss: 0.2741 - val_accuracy: 0.9228
# Epoch 11/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.2737 - accuracy: 0.9217 - val_loss: 0.2616 - val_accuracy: 0.9274
# Epoch 12/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.2622 - accuracy: 0.9250 - val_loss: 0.2509 - val_accuracy: 0.9300
# Epoch 13/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.2516 - accuracy: 0.9277 - val_loss: 0.2402 - val_accuracy: 0.9339
# Epoch 14/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.2418 - accuracy: 0.9303 - val_loss: 0.2314 - val_accuracy: 0.9358
# Epoch 15/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.2327 - accuracy: 0.9331 - val_loss: 0.2222 - val_accuracy: 0.9376
# Epoch 16/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.2244 - accuracy: 0.9349 - val_loss: 0.2147 - val_accuracy: 0.9406
# Epoch 17/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.2164 - accuracy: 0.9370 - val_loss: 0.2071 - val_accuracy: 0.9412
# Epoch 18/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.2091 - accuracy: 0.9395 - val_loss: 0.2012 - val_accuracy: 0.9450
# Epoch 19/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.2019 - accuracy: 0.9410 - val_loss: 0.1933 - val_accuracy: 0.9467
# Epoch 20/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.1955 - accuracy: 0.9435 - val_loss: 0.1876 - val_accuracy: 0.9481

# %%
best_model, best_accuracy = evaluate_model(saved_models, X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2819 - accuracy: 0.9213
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2225 - accuracy: 0.9385
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1793 - accuracy: 0.9486
# model: 3 accuracy: 94.86 %

# %% [markdown]
# #Trying different learning rates

# %% [markdown]
# Model 3 was our best model so far, using 20 epochs, so we take it and apply different learning rates to see if we can get better results.

# %%
model_4 = keras.models.clone_model(best_model)
opt_1 = optimizers.SGD(learning_rate=0.05, momentum=0.9)
model_4.compile(optimizer=opt_1, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_4.fit(X_train, y_train, epochs=20, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_4)
# Out:
# Epoch 1/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.1625 - accuracy: 0.9499 - val_loss: 0.0702 - val_accuracy: 0.9779
# Epoch 2/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0637 - accuracy: 0.9805 - val_loss: 0.0676 - val_accuracy: 0.9789
# Epoch 3/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.0452 - accuracy: 0.9856 - val_loss: 0.0805 - val_accuracy: 0.9793
# Epoch 4/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0361 - accuracy: 0.9885 - val_loss: 0.0783 - val_accuracy: 0.9790
# Epoch 5/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.0290 - accuracy: 0.9905 - val_loss: 0.0635 - val_accuracy: 0.9839
# Epoch 6/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0250 - accuracy: 0.9917 - val_loss: 0.0558 - val_accuracy: 0.9859
# Epoch 7/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.0221 - accuracy: 0.9927 - val_loss: 0.0579 - val_accuracy: 0.9871
# Epoch 8/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0154 - accuracy: 0.9945 - val_loss: 0.0688 - val_accuracy: 0.9830
# Epoch 9/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0173 - accuracy: 0.9946 - val_loss: 0.0718 - val_accuracy: 0.9851
# Epoch 10/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0150 - accuracy: 0.9951 - val_loss: 0.0859 - val_accuracy: 0.9836
# Epoch 11/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.0254 - accuracy: 0.9926 - val_loss: 0.0709 - val_accuracy: 0.9849
# Epoch 12/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0112 - accuracy: 0.9964 - val_loss: 0.1165 - val_accuracy: 0.9823
# Epoch 13/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 0.0803 - val_accuracy: 0.9857
# Epoch 14/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0183 - accuracy: 0.9944 - val_loss: 0.0910 - val_accuracy: 0.9839
# Epoch 15/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.0163 - accuracy: 0.9951 - val_loss: 0.1133 - val_accuracy: 0.9814
# Epoch 16/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0130 - accuracy: 0.9961 - val_loss: 0.0966 - val_accuracy: 0.9859
# Epoch 17/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0148 - accuracy: 0.9958 - val_loss: 0.2017 - val_accuracy: 0.9752
# Epoch 18/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.0190 - accuracy: 0.9950 - val_loss: 0.1059 - val_accuracy: 0.9839
# Epoch 19/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0135 - accuracy: 0.9961 - val_loss: 0.1538 - val_accuracy: 0.9811
# Epoch 20/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.0182 - accuracy: 0.9956 - val_loss: 0.1145 - val_accuracy: 0.9837

# %%
model_5 = keras.models.clone_model(best_model)
model_5.compile(optimizer=opt_2, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_5.fit(X_train, y_train, epochs=20, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_5)
# Out:
# Epoch 1/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.6994 - accuracy: 0.8128 - val_loss: 0.3073 - val_accuracy: 0.9120
# Epoch 2/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.2594 - accuracy: 0.9238 - val_loss: 0.2094 - val_accuracy: 0.9391
# Epoch 3/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.1893 - accuracy: 0.9449 - val_loss: 0.1567 - val_accuracy: 0.9551
# Epoch 4/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.1463 - accuracy: 0.9569 - val_loss: 0.1397 - val_accuracy: 0.9586
# Epoch 5/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.1207 - accuracy: 0.9643 - val_loss: 0.1141 - val_accuracy: 0.9661
# Epoch 6/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.1034 - accuracy: 0.9703 - val_loss: 0.0962 - val_accuracy: 0.9743
# Epoch 7/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.0910 - accuracy: 0.9736 - val_loss: 0.0909 - val_accuracy: 0.9736
# Epoch 8/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.0812 - accuracy: 0.9762 - val_loss: 0.0864 - val_accuracy: 0.9749
# Epoch 9/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.0747 - accuracy: 0.9785 - val_loss: 0.0816 - val_accuracy: 0.9778
# Epoch 10/20
# 1594/1594 [==============================] - 17s 11ms/step - loss: 0.0687 - accuracy: 0.9805 - val_loss: 0.0730 - val_accuracy: 0.9784
# Epoch 11/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.0639 - accuracy: 0.9814 - val_loss: 0.0654 - val_accuracy: 0.9800
# Epoch 12/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.0597 - accuracy: 0.9825 - val_loss: 0.0666 - val_accuracy: 0.9806
# Epoch 13/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0563 - accuracy: 0.9842 - val_loss: 0.0746 - val_accuracy: 0.9786
# Epoch 14/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.0533 - accuracy: 0.9841 - val_loss: 0.0587 - val_accuracy: 0.9839
# Epoch 15/20
# 1594/1594 [==============================] - 17s 10ms/step - loss: 0.0505 - accuracy: 0.9856 - val_loss: 0.0597 - val_accuracy: 0.9834
# Epoch 16/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.0480 - accuracy: 0.9859 - val_loss: 0.0596 - val_accuracy: 0.9814
# Epoch 17/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.0450 - accuracy: 0.9872 - val_loss: 0.0558 - val_accuracy: 0.9842
# Epoch 18/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.0434 - accuracy: 0.9869 - val_loss: 0.0560 - val_accuracy: 0.9839
# Epoch 19/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0417 - accuracy: 0.9877 - val_loss: 0.0506 - val_accuracy: 0.9861
# Epoch 20/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.0400 - accuracy: 0.9882 - val_loss: 0.0543 - val_accuracy: 0.9838

# %%
model_6 = keras.models.clone_model(best_model)
model_6.compile(optimizer=opt_3, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_6.fit(X_train, y_train, epochs=20, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_6)
# Out:
# Epoch 1/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.2342 - accuracy: 0.9290 - val_loss: 0.0787 - val_accuracy: 0.9757
# Epoch 2/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0718 - accuracy: 0.9780 - val_loss: 0.0558 - val_accuracy: 0.9846
# Epoch 3/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.0518 - accuracy: 0.9838 - val_loss: 0.0480 - val_accuracy: 0.9859
# Epoch 4/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.0405 - accuracy: 0.9875 - val_loss: 0.0480 - val_accuracy: 0.9847
# Epoch 5/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.0323 - accuracy: 0.9899 - val_loss: 0.0436 - val_accuracy: 0.9869
# Epoch 6/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.0261 - accuracy: 0.9922 - val_loss: 0.0425 - val_accuracy: 0.9877
# Epoch 7/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0218 - accuracy: 0.9936 - val_loss: 0.0414 - val_accuracy: 0.9876
# Epoch 8/20
# 1594/1594 [==============================] - 16s 10ms/step - loss: 0.0176 - accuracy: 0.9946 - val_loss: 0.0407 - val_accuracy: 0.9883
# Epoch 9/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0146 - accuracy: 0.9955 - val_loss: 0.0419 - val_accuracy: 0.9883
# Epoch 10/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0117 - accuracy: 0.9967 - val_loss: 0.0354 - val_accuracy: 0.9906
# Epoch 11/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.0090 - accuracy: 0.9977 - val_loss: 0.0389 - val_accuracy: 0.9900
# Epoch 12/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.0414 - val_accuracy: 0.9892
# Epoch 13/20
# 1594/1594 [==============================] - 15s 10ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.0458 - val_accuracy: 0.9887
# Epoch 14/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0047 - accuracy: 0.9991 - val_loss: 0.0404 - val_accuracy: 0.9899
# Epoch 15/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 0.0419 - val_accuracy: 0.9893
# Epoch 16/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 0.0478 - val_accuracy: 0.9889
# Epoch 17/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.0438 - val_accuracy: 0.9903
# Epoch 18/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0429 - val_accuracy: 0.9902
# Epoch 19/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.0431 - val_accuracy: 0.9897
# Epoch 20/20
# 1594/1594 [==============================] - 15s 9ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.0465 - val_accuracy: 0.9887

# %%
best_model, best_accuracy = evaluate_model(saved_models, X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2819 - accuracy: 0.9213
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2225 - accuracy: 0.9385
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1793 - accuracy: 0.9486
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1258 - accuracy: 0.9830
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0492 - accuracy: 0.9837
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0359 - accuracy: 0.9899
# model: 6 accuracy: 98.99 %

# %% [markdown]
# #Trying different architectures

# %% [markdown]
# Our last model was our best model, with 20 epochs and a learning rate of 0.01, we will try and explore different architectures.

# %%
model_7 = models.Sequential()
model_7.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
model_7.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_7.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform'))
model_7.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_7.add(layers.Flatten())
model_7.add(layers.Dense(64, activation='relu', kernel_initializer='he_uniform'))
model_7.add(layers.Dense(32, activation='relu', kernel_initializer='he_uniform'))
model_7.add(layers.Dense(10, activation='softmax'))

# %%
model_7.compile(optimizer=opt_3, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_7.fit(X_train, y_train, epochs=20, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_7)
# Out:
# Epoch 1/20
# 1594/1594 [==============================] - 39s 24ms/step - loss: 0.1699 - accuracy: 0.9465 - val_loss: 0.0624 - val_accuracy: 0.9822
# Epoch 2/20
# 1594/1594 [==============================] - 38s 24ms/step - loss: 0.0536 - accuracy: 0.9836 - val_loss: 0.0461 - val_accuracy: 0.9854
# Epoch 3/20
# 1594/1594 [==============================] - 38s 24ms/step - loss: 0.0375 - accuracy: 0.9887 - val_loss: 0.0466 - val_accuracy: 0.9864
# Epoch 4/20
# 1594/1594 [==============================] - 38s 24ms/step - loss: 0.0279 - accuracy: 0.9913 - val_loss: 0.0371 - val_accuracy: 0.9903
# Epoch 5/20
# 1594/1594 [==============================] - 38s 24ms/step - loss: 0.0221 - accuracy: 0.9930 - val_loss: 0.0698 - val_accuracy: 0.9812
# Epoch 6/20
# 1594/1594 [==============================] - 38s 24ms/step - loss: 0.0170 - accuracy: 0.9946 - val_loss: 0.0458 - val_accuracy: 0.9878
# Epoch 7/20
# 1594/1594 [==============================] - 38s 24ms/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.0583 - val_accuracy: 0.9860
# Epoch 8/20
# 1594/1594 [==============================] - 38s 24ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.0458 - val_accuracy: 0.9886
# Epoch 9/20
# 1594/1594 [==============================] - 39s 24ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.0464 - val_accuracy: 0.9900
# Epoch 10/20
# 1594/1594 [==============================] - 39s 24ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0517 - val_accuracy: 0.9892
# Epoch 11/20
# 1594/1594 [==============================] - 38s 24ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.0432 - val_accuracy: 0.9910
# Epoch 12/20
# 1594/1594 [==============================] - 39s 25ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.0409 - val_accuracy: 0.9916
# Epoch 13/20
# 1594/1594 [==============================] - 38s 24ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0432 - val_accuracy: 0.9917
# Epoch 14/20
# 1594/1594 [==============================] - 39s 25ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0472 - val_accuracy: 0.9916
# Epoch 15/20
# 1594/1594 [==============================] - 38s 24ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0568 - val_accuracy: 0.9883
# Epoch 16/20
# 1594/1594 [==============================] - 38s 24ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.0502 - val_accuracy: 0.9916
# Epoch 17/20
# 1594/1594 [==============================] - 39s 24ms/step - loss: 9.4385e-04 - accuracy: 0.9998 - val_loss: 0.0479 - val_accuracy: 0.9916
# Epoch 18/20
# 1594/1594 [==============================] - 38s 24ms/step - loss: 3.9373e-04 - accuracy: 0.9999 - val_loss: 0.0490 - val_accuracy: 0.9919
# Epoch 19/20
# 1594/1594 [==============================] - 38s 24ms/step - loss: 1.1661e-04 - accuracy: 1.0000 - val_loss: 0.0496 - val_accuracy: 0.9921
# Epoch 20/20
# 1594/1594 [==============================] - 37s 23ms/step - loss: 7.9806e-05 - accuracy: 1.0000 - val_loss: 0.0499 - val_accuracy: 0.9917

# %%
model_8 = models.Sequential()
model_8.add(layers.Conv2D(16, (3, 3), strides = (2, 2),activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
model_8.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_8.add(layers.Conv2D(32, (3, 3), strides = (2, 2),activation='relu', kernel_initializer='he_uniform'))
model_8.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_8.add(layers.Flatten())
model_8.add(layers.Dense(64, activation='relu', kernel_initializer='he_uniform'))
model_8.add(layers.Dense(32, activation='relu', kernel_initializer='he_uniform'))
model_8.add(layers.Dense(10, activation='softmax'))

# %%
model_8.compile(optimizer=opt_3, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_8.fit(X_train, y_train, epochs=20, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_8)
# Out:
# Epoch 1/20
# 1594/1594 [==============================] - 9s 5ms/step - loss: 0.4680 - accuracy: 0.8489 - val_loss: 0.1991 - val_accuracy: 0.9392
# Epoch 2/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.1821 - accuracy: 0.9444 - val_loss: 0.1945 - val_accuracy: 0.9431
# Epoch 3/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.1409 - accuracy: 0.9566 - val_loss: 0.1528 - val_accuracy: 0.9553
# Epoch 4/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.1221 - accuracy: 0.9622 - val_loss: 0.1369 - val_accuracy: 0.9581
# Epoch 5/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.1088 - accuracy: 0.9657 - val_loss: 0.1334 - val_accuracy: 0.9589
# Epoch 6/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.0979 - accuracy: 0.9692 - val_loss: 0.1385 - val_accuracy: 0.9579
# Epoch 7/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.0896 - accuracy: 0.9718 - val_loss: 0.1255 - val_accuracy: 0.9631
# Epoch 8/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.0859 - accuracy: 0.9728 - val_loss: 0.1253 - val_accuracy: 0.9621
# Epoch 9/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.0790 - accuracy: 0.9752 - val_loss: 0.1146 - val_accuracy: 0.9670
# Epoch 10/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.0744 - accuracy: 0.9767 - val_loss: 0.1182 - val_accuracy: 0.9658
# Epoch 11/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.0724 - accuracy: 0.9771 - val_loss: 0.1181 - val_accuracy: 0.9666
# Epoch 12/20
# 1594/1594 [==============================] - 9s 5ms/step - loss: 0.0670 - accuracy: 0.9785 - val_loss: 0.1365 - val_accuracy: 0.9628
# Epoch 13/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.0648 - accuracy: 0.9795 - val_loss: 0.1187 - val_accuracy: 0.9671
# Epoch 14/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.0600 - accuracy: 0.9809 - val_loss: 0.1289 - val_accuracy: 0.9640
# Epoch 15/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.0592 - accuracy: 0.9808 - val_loss: 0.1433 - val_accuracy: 0.9609
# Epoch 16/20
# 1594/1594 [==============================] - 10s 6ms/step - loss: 0.0568 - accuracy: 0.9815 - val_loss: 0.1113 - val_accuracy: 0.9708
# Epoch 17/20
# 1594/1594 [==============================] - 10s 6ms/step - loss: 0.0554 - accuracy: 0.9823 - val_loss: 0.1229 - val_accuracy: 0.9678
# Epoch 18/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.0552 - accuracy: 0.9823 - val_loss: 0.1123 - val_accuracy: 0.9696
# Epoch 19/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.0526 - accuracy: 0.9829 - val_loss: 0.1385 - val_accuracy: 0.9633
# Epoch 20/20
# 1594/1594 [==============================] - 8s 5ms/step - loss: 0.0512 - accuracy: 0.9831 - val_loss: 0.1016 - val_accuracy: 0.9728

# %%
model_9 = models.Sequential()
model_9.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
model_9.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_9.add(layers.Conv2D(32, (5, 5), activation='relu', kernel_initializer='he_uniform'))
model_9.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_9.add(layers.Flatten())
model_9.add(layers.Dense(32, activation='relu', kernel_initializer='he_uniform'))
model_9.add(layers.Dense(10, activation='softmax'))

# %%
model_9.compile(optimizer=opt_3, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_9.fit(X_train, y_train, epochs=20, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_9)
# Out:
# Epoch 1/20
# 1594/1594 [==============================] - 52s 32ms/step - loss: 0.1726 - accuracy: 0.9460 - val_loss: 0.0771 - val_accuracy: 0.9759
# Epoch 2/20
# 1594/1594 [==============================] - 51s 32ms/step - loss: 0.0575 - accuracy: 0.9815 - val_loss: 0.0681 - val_accuracy: 0.9806
# Epoch 3/20
# 1594/1594 [==============================] - 51s 32ms/step - loss: 0.0389 - accuracy: 0.9880 - val_loss: 0.0500 - val_accuracy: 0.9853
# Epoch 4/20
# 1594/1594 [==============================] - 52s 32ms/step - loss: 0.0311 - accuracy: 0.9900 - val_loss: 0.0389 - val_accuracy: 0.9887
# Epoch 5/20
# 1594/1594 [==============================] - 50s 31ms/step - loss: 0.0229 - accuracy: 0.9926 - val_loss: 0.0421 - val_accuracy: 0.9880
# Epoch 6/20
# 1594/1594 [==============================] - 51s 32ms/step - loss: 0.0170 - accuracy: 0.9948 - val_loss: 0.0431 - val_accuracy: 0.9882
# Epoch 7/20
# 1594/1594 [==============================] - 49s 31ms/step - loss: 0.0145 - accuracy: 0.9953 - val_loss: 0.0488 - val_accuracy: 0.9881
# Epoch 8/20
# 1594/1594 [==============================] - 49s 31ms/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 0.0552 - val_accuracy: 0.9851
# Epoch 9/20
# 1594/1594 [==============================] - 50s 31ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.0453 - val_accuracy: 0.9874
# Epoch 10/20
# 1594/1594 [==============================] - 50s 31ms/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0414 - val_accuracy: 0.9892
# Epoch 11/20
# 1594/1594 [==============================] - 49s 31ms/step - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.0435 - val_accuracy: 0.9888
# Epoch 12/20
# 1594/1594 [==============================] - 49s 31ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.0510 - val_accuracy: 0.9888
# Epoch 13/20
# 1594/1594 [==============================] - 49s 31ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.0438 - val_accuracy: 0.9892
# Epoch 14/20
# 1594/1594 [==============================] - 49s 31ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0472 - val_accuracy: 0.9894
# Epoch 15/20
# 1594/1594 [==============================] - 50s 31ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0464 - val_accuracy: 0.9901
# Epoch 16/20
# 1594/1594 [==============================] - 49s 31ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0459 - val_accuracy: 0.9899
# Epoch 17/20
# 1594/1594 [==============================] - 50s 31ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0470 - val_accuracy: 0.9897
# Epoch 18/20
# 1594/1594 [==============================] - 50s 31ms/step - loss: 7.6235e-04 - accuracy: 0.9999 - val_loss: 0.0467 - val_accuracy: 0.9909
# Epoch 19/20
# 1594/1594 [==============================] - 50s 31ms/step - loss: 3.2585e-04 - accuracy: 0.9999 - val_loss: 0.0473 - val_accuracy: 0.9906
# Epoch 20/20
# 1594/1594 [==============================] - 49s 31ms/step - loss: 2.3030e-04 - accuracy: 1.0000 - val_loss: 0.0477 - val_accuracy: 0.9907

# %%
model_10 = models.Sequential()
model_10.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
model_10.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_10.add(layers.Flatten())
model_10.add(layers.Dense(32, activation='relu', kernel_initializer='he_uniform'))
model_10.add(layers.Dense(10, activation='softmax'))

# %%
model_10.compile(optimizer=opt_3, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_10.fit(X_train, y_train, epochs=20, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_10)
# Out:
# Epoch 1/20
# 1594/1594 [==============================] - 64s 40ms/step - loss: 0.1959 - accuracy: 0.9406 - val_loss: 0.0821 - val_accuracy: 0.9748
# Epoch 2/20
# 1594/1594 [==============================] - 62s 39ms/step - loss: 0.0659 - accuracy: 0.9802 - val_loss: 0.0697 - val_accuracy: 0.9782
# Epoch 3/20
# 1594/1594 [==============================] - 64s 40ms/step - loss: 0.0439 - accuracy: 0.9867 - val_loss: 0.0558 - val_accuracy: 0.9829
# Epoch 4/20
# 1594/1594 [==============================] - 62s 39ms/step - loss: 0.0306 - accuracy: 0.9906 - val_loss: 0.0552 - val_accuracy: 0.9841
# Epoch 5/20
# 1594/1594 [==============================] - 63s 40ms/step - loss: 0.0213 - accuracy: 0.9936 - val_loss: 0.0554 - val_accuracy: 0.9846
# Epoch 6/20
# 1594/1594 [==============================] - 60s 38ms/step - loss: 0.0152 - accuracy: 0.9958 - val_loss: 0.0527 - val_accuracy: 0.9848
# Epoch 7/20
# 1594/1594 [==============================] - 59s 37ms/step - loss: 0.0104 - accuracy: 0.9971 - val_loss: 0.0544 - val_accuracy: 0.9854
# Epoch 8/20
# 1594/1594 [==============================] - 58s 36ms/step - loss: 0.0066 - accuracy: 0.9985 - val_loss: 0.0571 - val_accuracy: 0.9846
# Epoch 9/20
# 1594/1594 [==============================] - 59s 37ms/step - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.0556 - val_accuracy: 0.9859
# Epoch 10/20
# 1594/1594 [==============================] - 59s 37ms/step - loss: 0.0031 - accuracy: 0.9996 - val_loss: 0.0557 - val_accuracy: 0.9858
# Epoch 11/20
# 1594/1594 [==============================] - 59s 37ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.0557 - val_accuracy: 0.9872
# Epoch 12/20
# 1594/1594 [==============================] - 59s 37ms/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.0559 - val_accuracy: 0.9873
# Epoch 13/20
# 1594/1594 [==============================] - 59s 37ms/step - loss: 8.9538e-04 - accuracy: 1.0000 - val_loss: 0.0582 - val_accuracy: 0.9871
# Epoch 14/20
# 1594/1594 [==============================] - 59s 37ms/step - loss: 7.1240e-04 - accuracy: 1.0000 - val_loss: 0.0589 - val_accuracy: 0.9868
# Epoch 15/20
# 1594/1594 [==============================] - 60s 38ms/step - loss: 6.1869e-04 - accuracy: 1.0000 - val_loss: 0.0597 - val_accuracy: 0.9867
# Epoch 16/20
# 1594/1594 [==============================] - 60s 38ms/step - loss: 5.5715e-04 - accuracy: 1.0000 - val_loss: 0.0601 - val_accuracy: 0.9868
# Epoch 17/20
# 1594/1594 [==============================] - 60s 38ms/step - loss: 5.0162e-04 - accuracy: 1.0000 - val_loss: 0.0608 - val_accuracy: 0.9871
# Epoch 18/20
# 1594/1594 [==============================] - 60s 37ms/step - loss: 4.5719e-04 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9872
# Epoch 19/20
# 1594/1594 [==============================] - 59s 37ms/step - loss: 4.1889e-04 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9870
# Epoch 20/20
# 1594/1594 [==============================] - 60s 38ms/step - loss: 3.8041e-04 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9871

# %%
best_model, best_accuracy = evaluate_model(saved_models, X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2819 - accuracy: 0.9213
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2225 - accuracy: 0.9385
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1793 - accuracy: 0.9486
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1258 - accuracy: 0.9830
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0492 - accuracy: 0.9837
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0359 - accuracy: 0.9899
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0375 - accuracy: 0.9920
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1074 - accuracy: 0.9716
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0484 - accuracy: 0.9897
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0564 - accuracy: 0.9861
# model: 7 accuracy: 99.20 %

# %% [markdown]
# #Trying different batch sizes

# %% [markdown]
# Our last model always seem to be our best model, reaching an accuarcy of 99.3,
# we used 20 epochs, a learning rate of 0.01 and our architecture was a single convultion layer containing 128 filters of size (3, 3) and a max pooling layer followed by a densle layer of 32 neurons.
# we will countinue with it and decide to change the batch size this time around.

# %%
model_11 = keras.models.clone_model(best_model)
model_11.compile(optimizer=opt_3, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_11.fit(X_train, y_train, epochs=20, batch_size=16, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_11)
# Out:
# Epoch 1/20
# 3188/3188 [==============================] - 47s 15ms/step - loss: 0.1431 - accuracy: 0.9550 - val_loss: 0.0789 - val_accuracy: 0.9780
# Epoch 2/20
# 3188/3188 [==============================] - 47s 15ms/step - loss: 0.0540 - accuracy: 0.9834 - val_loss: 0.0721 - val_accuracy: 0.9784
# Epoch 3/20
# 3188/3188 [==============================] - 46s 14ms/step - loss: 0.0372 - accuracy: 0.9884 - val_loss: 0.0496 - val_accuracy: 0.9856
# Epoch 4/20
# 3188/3188 [==============================] - 47s 15ms/step - loss: 0.0289 - accuracy: 0.9903 - val_loss: 0.0403 - val_accuracy: 0.9892
# Epoch 5/20
# 3188/3188 [==============================] - 46s 14ms/step - loss: 0.0227 - accuracy: 0.9923 - val_loss: 0.0423 - val_accuracy: 0.9882
# Epoch 6/20
# 3188/3188 [==============================] - 46s 15ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.0482 - val_accuracy: 0.9872
# Epoch 7/20
# 3188/3188 [==============================] - 46s 14ms/step - loss: 0.0171 - accuracy: 0.9942 - val_loss: 0.0589 - val_accuracy: 0.9859
# Epoch 8/20
# 3188/3188 [==============================] - 45s 14ms/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.0435 - val_accuracy: 0.9891
# Epoch 9/20
# 3188/3188 [==============================] - 45s 14ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.0552 - val_accuracy: 0.9866
# Epoch 10/20
# 3188/3188 [==============================] - 45s 14ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.0434 - val_accuracy: 0.9900
# Epoch 11/20
# 3188/3188 [==============================] - 45s 14ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0606 - val_accuracy: 0.9882
# Epoch 12/20
# 3188/3188 [==============================] - 45s 14ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.0592 - val_accuracy: 0.9863
# Epoch 13/20
# 3188/3188 [==============================] - 45s 14ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0446 - val_accuracy: 0.9906
# Epoch 14/20
# 3188/3188 [==============================] - 46s 14ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.0507 - val_accuracy: 0.9900
# Epoch 15/20
# 3188/3188 [==============================] - 47s 15ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0556 - val_accuracy: 0.9887
# Epoch 16/20
# 3188/3188 [==============================] - 46s 14ms/step - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.0529 - val_accuracy: 0.9894
# Epoch 17/20
# 3188/3188 [==============================] - 46s 14ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0665 - val_accuracy: 0.9860
# Epoch 18/20
# 3188/3188 [==============================] - 47s 15ms/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.0753 - val_accuracy: 0.9856
# Epoch 19/20
# 3188/3188 [==============================] - 48s 15ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0615 - val_accuracy: 0.9882
# Epoch 20/20
# 3188/3188 [==============================] - 49s 15ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.0650 - val_accuracy: 0.9877

# %%
model_12 = keras.models.clone_model(best_model)
model_12.compile(optimizer=opt_3, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_12.fit(X_train, y_train, epochs=20, batch_size=64, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_12)
# Out:
# Epoch 1/20
# 797/797 [==============================] - 35s 44ms/step - loss: 0.2320 - accuracy: 0.9256 - val_loss: 0.0718 - val_accuracy: 0.9778
# Epoch 2/20
# 797/797 [==============================] - 34s 43ms/step - loss: 0.0651 - accuracy: 0.9798 - val_loss: 0.0569 - val_accuracy: 0.9826
# Epoch 3/20
# 797/797 [==============================] - 34s 43ms/step - loss: 0.0455 - accuracy: 0.9859 - val_loss: 0.0499 - val_accuracy: 0.9854
# Epoch 4/20
# 797/797 [==============================] - 35s 43ms/step - loss: 0.0357 - accuracy: 0.9890 - val_loss: 0.0512 - val_accuracy: 0.9851
# Epoch 5/20
# 797/797 [==============================] - 34s 43ms/step - loss: 0.0286 - accuracy: 0.9911 - val_loss: 0.0517 - val_accuracy: 0.9843
# Epoch 6/20
# 797/797 [==============================] - 34s 43ms/step - loss: 0.0246 - accuracy: 0.9924 - val_loss: 0.0431 - val_accuracy: 0.9878
# Epoch 7/20
# 797/797 [==============================] - 34s 43ms/step - loss: 0.0190 - accuracy: 0.9943 - val_loss: 0.0454 - val_accuracy: 0.9876
# Epoch 8/20
# 797/797 [==============================] - 34s 43ms/step - loss: 0.0160 - accuracy: 0.9947 - val_loss: 0.0439 - val_accuracy: 0.9874
# Epoch 9/20
# 797/797 [==============================] - 34s 43ms/step - loss: 0.0145 - accuracy: 0.9952 - val_loss: 0.0440 - val_accuracy: 0.9892
# Epoch 10/20
# 797/797 [==============================] - 35s 44ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0428 - val_accuracy: 0.9882
# Epoch 11/20
# 797/797 [==============================] - 35s 43ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 0.0453 - val_accuracy: 0.9882
# Epoch 12/20
# 797/797 [==============================] - 34s 43ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.0498 - val_accuracy: 0.9880
# Epoch 13/20
# 797/797 [==============================] - 34s 43ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0478 - val_accuracy: 0.9881
# Epoch 14/20
# 797/797 [==============================] - 34s 43ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0474 - val_accuracy: 0.9887
# Epoch 15/20
# 797/797 [==============================] - 36s 45ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.0463 - val_accuracy: 0.9888
# Epoch 16/20
# 797/797 [==============================] - 35s 44ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.0493 - val_accuracy: 0.9879
# Epoch 17/20
# 797/797 [==============================] - 35s 43ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0484 - val_accuracy: 0.9900
# Epoch 18/20
# 797/797 [==============================] - 35s 44ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0456 - val_accuracy: 0.9899
# Epoch 19/20
# 797/797 [==============================] - 35s 44ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0460 - val_accuracy: 0.9901
# Epoch 20/20
# 797/797 [==============================] - 35s 44ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0505 - val_accuracy: 0.9892

# %%
best_model, best_accuracy = evaluate_model(saved_models, X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2819 - accuracy: 0.9213
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2225 - accuracy: 0.9385
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1793 - accuracy: 0.9486
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1258 - accuracy: 0.9830
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0492 - accuracy: 0.9837
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0359 - accuracy: 0.9899
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0375 - accuracy: 0.9920
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1074 - accuracy: 0.9716
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0484 - accuracy: 0.9897
# 313/313 [==============================] - 4s 13ms/step - loss: 0.0564 - accuracy: 0.9861
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0629 - accuracy: 0.9880
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0367 - accuracy: 0.9910
# model: 7 accuracy: 99.20 %

# %% [markdown]
# #Trying different activation functions

# %% [markdown]
# It seems taht we lucked out and started with the perfect batch size, because model 9 is still our best model, we will try and experiment with different activation functions to see if we can get a better result.

# %%
model_13 = models.Sequential()
model_13.add(layers.Conv2D(32, (3, 3), activation='tanh', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
model_13.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_13.add(layers.Conv2D(32, (3, 3), activation='tanh', kernel_initializer='he_uniform'))
model_13.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_13.add(layers.Flatten())
model_13.add(layers.Dense(64, activation='tanh', kernel_initializer='he_uniform'))
model_13.add(layers.Dense(32, activation='tanh', kernel_initializer='he_uniform'))
model_13.add(layers.Dense(10, activation='softmax'))

# %%
model_13.compile(optimizer=opt_3, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_13.fit(X_train, y_train, epochs=10, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_13)
# Out:
# Epoch 1/10
# 1594/1594 [==============================] - 44s 27ms/step - loss: 0.1860 - accuracy: 0.9461 - val_loss: 0.0713 - val_accuracy: 0.9792
# Epoch 2/10
# 1594/1594 [==============================] - 42s 27ms/step - loss: 0.0603 - accuracy: 0.9818 - val_loss: 0.0529 - val_accuracy: 0.9854
# Epoch 3/10
# 1594/1594 [==============================] - 43s 27ms/step - loss: 0.0402 - accuracy: 0.9881 - val_loss: 0.0458 - val_accuracy: 0.9854
# Epoch 4/10
# 1594/1594 [==============================] - 44s 28ms/step - loss: 0.0272 - accuracy: 0.9920 - val_loss: 0.0430 - val_accuracy: 0.9873
# Epoch 5/10
# 1594/1594 [==============================] - 42s 26ms/step - loss: 0.0200 - accuracy: 0.9941 - val_loss: 0.0479 - val_accuracy: 0.9867
# Epoch 6/10
# 1594/1594 [==============================] - 40s 25ms/step - loss: 0.0151 - accuracy: 0.9957 - val_loss: 0.0382 - val_accuracy: 0.9886
# Epoch 7/10
# 1594/1594 [==============================] - 40s 25ms/step - loss: 0.0106 - accuracy: 0.9972 - val_loss: 0.0367 - val_accuracy: 0.9900
# Epoch 8/10
# 1594/1594 [==============================] - 39s 25ms/step - loss: 0.0067 - accuracy: 0.9987 - val_loss: 0.0372 - val_accuracy: 0.9889
# Epoch 9/10
# 1594/1594 [==============================] - 41s 26ms/step - loss: 0.0060 - accuracy: 0.9987 - val_loss: 0.0380 - val_accuracy: 0.9898
# Epoch 10/10
# 1594/1594 [==============================] - 41s 26ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.0349 - val_accuracy: 0.9903

# %%
model_14 = models.Sequential()
model_14.add(layers.Conv2D(32, (3, 3), activation='selu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
model_14.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_14.add(layers.Conv2D(32, (3, 3), activation='selu', kernel_initializer='he_uniform'))
model_14.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_14.add(layers.Flatten())
model_14.add(layers.Dense(64, activation='selu', kernel_initializer='he_uniform'))
model_14.add(layers.Dense(32, activation='selu', kernel_initializer='he_uniform'))
model_14.add(layers.Dense(10, activation='softmax'))

# %%
model_14.compile(optimizer=opt_3, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_14.fit(X_train, y_train, epochs=10, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_14)
# Out:
# Epoch 1/10
# 1594/1594 [==============================] - 47s 29ms/step - loss: 0.1499 - accuracy: 0.9548 - val_loss: 0.0817 - val_accuracy: 0.9734
# Epoch 2/10
# 1594/1594 [==============================] - 46s 29ms/step - loss: 0.0539 - accuracy: 0.9832 - val_loss: 0.0557 - val_accuracy: 0.9841
# Epoch 3/10
# 1594/1594 [==============================] - 46s 29ms/step - loss: 0.0357 - accuracy: 0.9891 - val_loss: 0.0731 - val_accuracy: 0.9817
# Epoch 4/10
# 1594/1594 [==============================] - 46s 29ms/step - loss: 0.0253 - accuracy: 0.9921 - val_loss: 0.0517 - val_accuracy: 0.9858
# Epoch 5/10
# 1594/1594 [==============================] - 47s 30ms/step - loss: 0.0173 - accuracy: 0.9946 - val_loss: 0.0567 - val_accuracy: 0.9851
# Epoch 6/10
# 1594/1594 [==============================] - 47s 29ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.0519 - val_accuracy: 0.9868
# Epoch 7/10
# 1594/1594 [==============================] - 47s 29ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 0.0529 - val_accuracy: 0.9884
# Epoch 8/10
# 1594/1594 [==============================] - 51s 32ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0515 - val_accuracy: 0.9892
# Epoch 9/10
# 1594/1594 [==============================] - 48s 30ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.0543 - val_accuracy: 0.9892
# Epoch 10/10
# 1594/1594 [==============================] - 47s 30ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0496 - val_accuracy: 0.9890

# %%
from keras.layers import LeakyReLU
model_15 = models.Sequential()
model_15.add(layers.Conv2D(32, (3, 3), kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
model_15.add(LeakyReLU(alpha=0.05))
model_15.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_15.add(layers.Conv2D(32, (3, 3), kernel_initializer='he_uniform'))
model_15.add(LeakyReLU(alpha=0.05))
model_15.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_15.add(layers.Flatten())
model_15.add(layers.Dense(64, kernel_initializer='he_uniform'))
model_15.add(LeakyReLU(alpha=0.05))
model_15.add(layers.Dense(32, kernel_initializer='he_uniform'))
model_15.add(LeakyReLU(alpha=0.05))
model_15.add(layers.Dense(10, activation='softmax'))

# %%
model_15.compile(optimizer=opt_3, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_15.fit(X_train, y_train, epochs=10, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_15)
# Out:
# Epoch 1/10
# 1594/1594 [==============================] - 45s 28ms/step - loss: 0.1644 - accuracy: 0.9474 - val_loss: 0.0787 - val_accuracy: 0.9768
# Epoch 2/10
# 1594/1594 [==============================] - 45s 28ms/step - loss: 0.0558 - accuracy: 0.9822 - val_loss: 0.0449 - val_accuracy: 0.9867
# Epoch 3/10
# 1594/1594 [==============================] - 46s 29ms/step - loss: 0.0379 - accuracy: 0.9879 - val_loss: 0.0490 - val_accuracy: 0.9863
# Epoch 4/10
# 1594/1594 [==============================] - 45s 28ms/step - loss: 0.0291 - accuracy: 0.9905 - val_loss: 0.0433 - val_accuracy: 0.9893
# Epoch 5/10
# 1594/1594 [==============================] - 46s 29ms/step - loss: 0.0221 - accuracy: 0.9926 - val_loss: 0.0434 - val_accuracy: 0.9887
# Epoch 6/10
# 1594/1594 [==============================] - 48s 30ms/step - loss: 0.0162 - accuracy: 0.9947 - val_loss: 0.0517 - val_accuracy: 0.9879
# Epoch 7/10
# 1594/1594 [==============================] - 45s 28ms/step - loss: 0.0133 - accuracy: 0.9956 - val_loss: 0.0406 - val_accuracy: 0.9902
# Epoch 8/10
# 1594/1594 [==============================] - 45s 28ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.0471 - val_accuracy: 0.9889
# Epoch 9/10
# 1594/1594 [==============================] - 44s 28ms/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.0475 - val_accuracy: 0.9901
# Epoch 10/10
# 1594/1594 [==============================] - 46s 29ms/step - loss: 0.0063 - accuracy: 0.9982 - val_loss: 0.0462 - val_accuracy: 0.9906

# %%
best_model, best_accuracy = evaluate_model(saved_models, X_test, y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2819 - accuracy: 0.9213
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2225 - accuracy: 0.9385
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1793 - accuracy: 0.9486
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1258 - accuracy: 0.9830
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0492 - accuracy: 0.9837
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0359 - accuracy: 0.9899
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0375 - accuracy: 0.9920
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1074 - accuracy: 0.9716
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0484 - accuracy: 0.9897
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0564 - accuracy: 0.9861
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0629 - accuracy: 0.9880
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0367 - accuracy: 0.9910
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0379 - accuracy: 0.9893
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0397 - accuracy: 0.9900
# 313/313 [==============================] - 4s 12ms/step - loss: 0.0418 - accuracy: 0.9891
# model: 7 accuracy: 99.20 %

# %% [markdown]
# #Trying different optimizers

# %%
model_16 = keras.models.clone_model(best_model)
model_16.compile(optimizer=opt_4, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_16.fit(X_train, y_train, epochs=10, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_16)
# Out:
# Epoch 1/10
# 1594/1594 [==============================] - 43s 27ms/step - loss: 0.1747 - accuracy: 0.9476 - val_loss: 0.1039 - val_accuracy: 0.9746
# Epoch 2/10
# 1594/1594 [==============================] - 42s 26ms/step - loss: 0.1054 - accuracy: 0.9706 - val_loss: 0.0877 - val_accuracy: 0.9762
# Epoch 3/10
# 1594/1594 [==============================] - 43s 27ms/step - loss: 0.0964 - accuracy: 0.9750 - val_loss: 0.0987 - val_accuracy: 0.9740
# Epoch 4/10
# 1594/1594 [==============================] - 42s 27ms/step - loss: 0.0864 - accuracy: 0.9776 - val_loss: 0.1287 - val_accuracy: 0.9674
# Epoch 5/10
# 1594/1594 [==============================] - 43s 27ms/step - loss: 0.0790 - accuracy: 0.9804 - val_loss: 0.0895 - val_accuracy: 0.9796
# Epoch 6/10
# 1594/1594 [==============================] - 43s 27ms/step - loss: 0.0797 - accuracy: 0.9802 - val_loss: 0.1216 - val_accuracy: 0.9718
# Epoch 7/10
# 1594/1594 [==============================] - 43s 27ms/step - loss: 0.0726 - accuracy: 0.9827 - val_loss: 0.1088 - val_accuracy: 0.9769
# Epoch 8/10
# 1594/1594 [==============================] - 42s 27ms/step - loss: 0.0713 - accuracy: 0.9834 - val_loss: 0.0845 - val_accuracy: 0.9823
# Epoch 9/10
# 1594/1594 [==============================] - 42s 26ms/step - loss: 0.0699 - accuracy: 0.9848 - val_loss: 0.1166 - val_accuracy: 0.9742
# Epoch 10/10
# 1594/1594 [==============================] - 42s 26ms/step - loss: 0.0728 - accuracy: 0.9846 - val_loss: 0.0876 - val_accuracy: 0.9829

# %%
model_17 = keras.models.clone_model(best_model)
model_17.compile(optimizer=opt_5, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_17.fit(X_train, y_train, epochs=10, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_17)
# Out:
# Epoch 1/10
# 1594/1594 [==============================] - 43s 27ms/step - loss: 0.2233 - accuracy: 0.9425 - val_loss: 0.1090 - val_accuracy: 0.9681
# Epoch 2/10
# 1594/1594 [==============================] - 43s 27ms/step - loss: 0.1465 - accuracy: 0.9668 - val_loss: 0.1845 - val_accuracy: 0.9622
# Epoch 3/10
# 1594/1594 [==============================] - 43s 27ms/step - loss: 0.1619 - accuracy: 0.9663 - val_loss: 0.1445 - val_accuracy: 0.9680
# Epoch 4/10
# 1594/1594 [==============================] - 44s 27ms/step - loss: 0.1577 - accuracy: 0.9679 - val_loss: 0.2056 - val_accuracy: 0.9568
# Epoch 5/10
# 1594/1594 [==============================] - 44s 28ms/step - loss: 0.1684 - accuracy: 0.9664 - val_loss: 0.1468 - val_accuracy: 0.9687
# Epoch 6/10
# 1594/1594 [==============================] - 41s 26ms/step - loss: 0.1827 - accuracy: 0.9643 - val_loss: 0.1900 - val_accuracy: 0.9576
# Epoch 7/10
# 1594/1594 [==============================] - 41s 26ms/step - loss: 0.1842 - accuracy: 0.9660 - val_loss: 0.1621 - val_accuracy: 0.9632
# Epoch 8/10
# 1594/1594 [==============================] - 42s 26ms/step - loss: 0.1942 - accuracy: 0.9614 - val_loss: 0.1562 - val_accuracy: 0.9700
# Epoch 9/10
# 1594/1594 [==============================] - 44s 27ms/step - loss: 0.1938 - accuracy: 0.9604 - val_loss: 0.1630 - val_accuracy: 0.9683
# Epoch 10/10
# 1594/1594 [==============================] - 44s 28ms/step - loss: 0.1871 - accuracy: 0.9610 - val_loss: 0.4321 - val_accuracy: 0.9576

# %%
best_model, best_accuracy = evaluate_model(saved_models, X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 5ms/step - loss: 0.2819 - accuracy: 0.9213
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2225 - accuracy: 0.9385
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1793 - accuracy: 0.9486
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1258 - accuracy: 0.9830
# 313/313 [==============================] - 1s 5ms/step - loss: 0.0492 - accuracy: 0.9837
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0359 - accuracy: 0.9899
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0375 - accuracy: 0.9920
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1074 - accuracy: 0.9716
# 313/313 [==============================] - 4s 11ms/step - loss: 0.0484 - accuracy: 0.9897
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0564 - accuracy: 0.9861
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0629 - accuracy: 0.9880
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0367 - accuracy: 0.9910
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0379 - accuracy: 0.9893
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0397 - accuracy: 0.9900
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0418 - accuracy: 0.9891
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0817 - accuracy: 0.9840
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4740 - accuracy: 0.9514
# model: 7 accuracy: 99.20 %

# %% [markdown]
# #Trying different dropout rates

# %% [markdown]
# Model 7 is still our best model, we try adding dropout layers and see what diiference it will make.

# %%
from keras.layers import Dropout

# %%
model_18 = models.Sequential()
model_18.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
model_18.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.4))
model_18.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform'))
model_18.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_18.add(layers.Flatten())
model_18.add(layers.Dense(64, activation='relu', kernel_initializer='he_uniform'))
model_18.add(layers.Dense(32, activation='relu', kernel_initializer='he_uniform'))
model.add(Dropout(0.4))
model_18.add(layers.Dense(10, activation='softmax'))

# %%
opt_3 = optimizers.SGD(learning_rate=0.01, momentum=0.9)
model_18.compile(optimizer=opt_3, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_18.fit(X_train, y_train, epochs=10, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_18)
# Out:
# Epoch 1/10
# 1594/1594 [==============================] - 43s 27ms/step - loss: 0.1758 - accuracy: 0.9442 - val_loss: 0.0683 - val_accuracy: 0.9794
# Epoch 2/10
# 1594/1594 [==============================] - 42s 26ms/step - loss: 0.0586 - accuracy: 0.9822 - val_loss: 0.0570 - val_accuracy: 0.9833
# Epoch 3/10
# 1594/1594 [==============================] - 42s 27ms/step - loss: 0.0417 - accuracy: 0.9872 - val_loss: 0.0508 - val_accuracy: 0.9843
# Epoch 4/10
# 1594/1594 [==============================] - 41s 26ms/step - loss: 0.0317 - accuracy: 0.9902 - val_loss: 0.0538 - val_accuracy: 0.9849
# Epoch 5/10
# 1594/1594 [==============================] - 42s 27ms/step - loss: 0.0264 - accuracy: 0.9913 - val_loss: 0.0455 - val_accuracy: 0.9879
# Epoch 6/10
# 1594/1594 [==============================] - 44s 27ms/step - loss: 0.0197 - accuracy: 0.9936 - val_loss: 0.0431 - val_accuracy: 0.9896
# Epoch 7/10
# 1594/1594 [==============================] - 41s 26ms/step - loss: 0.0168 - accuracy: 0.9944 - val_loss: 0.0478 - val_accuracy: 0.9886
# Epoch 8/10
# 1594/1594 [==============================] - 41s 26ms/step - loss: 0.0117 - accuracy: 0.9963 - val_loss: 0.0526 - val_accuracy: 0.9870
# Epoch 9/10
# 1594/1594 [==============================] - 41s 26ms/step - loss: 0.0110 - accuracy: 0.9967 - val_loss: 0.0493 - val_accuracy: 0.9883
# Epoch 10/10
# 1594/1594 [==============================] - 41s 26ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 0.0506 - val_accuracy: 0.9893

# %%
model_19 = models.Sequential()
model_19.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
model_19.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_19.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform'))
model_19.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_19.add(Dropout(0.4))
model_19.add(layers.Flatten())
model_19.add(layers.Dense(64, activation='relu', kernel_initializer='he_uniform'))
model_19.add(Dropout(0.4))
model_19.add(layers.Dense(32, activation='relu', kernel_initializer='he_uniform'))
model_19.add(Dropout(0.4))
model_19.add(layers.Dense(10, activation='softmax'))

# %%
opt_3 = optimizers.SGD(learning_rate=0.01, momentum=0.9)
model_19.compile(optimizer=opt_3, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_19.fit(X_train, y_train, epochs=10, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_19)
# Out:
# Epoch 1/10
# 1594/1594 [==============================] - 44s 27ms/step - loss: 0.7141 - accuracy: 0.7766 - val_loss: 0.1351 - val_accuracy: 0.9649
# Epoch 2/10
# 1594/1594 [==============================] - 44s 27ms/step - loss: 0.3335 - accuracy: 0.9113 - val_loss: 0.0799 - val_accuracy: 0.9796
# Epoch 3/10
# 1594/1594 [==============================] - 45s 28ms/step - loss: 0.2533 - accuracy: 0.9313 - val_loss: 0.0801 - val_accuracy: 0.9797
# Epoch 4/10
# 1594/1594 [==============================] - 43s 27ms/step - loss: 0.2210 - accuracy: 0.9391 - val_loss: 0.0682 - val_accuracy: 0.9827
# Epoch 5/10
# 1594/1594 [==============================] - 44s 27ms/step - loss: 0.2054 - accuracy: 0.9452 - val_loss: 0.0643 - val_accuracy: 0.9828
# Epoch 6/10
# 1594/1594 [==============================] - 43s 27ms/step - loss: 0.1856 - accuracy: 0.9496 - val_loss: 0.0556 - val_accuracy: 0.9856
# Epoch 7/10
# 1594/1594 [==============================] - 47s 30ms/step - loss: 0.1797 - accuracy: 0.9518 - val_loss: 0.0580 - val_accuracy: 0.9839
# Epoch 8/10
# 1594/1594 [==============================] - 47s 29ms/step - loss: 0.1642 - accuracy: 0.9555 - val_loss: 0.0554 - val_accuracy: 0.9849
# Epoch 9/10
# 1594/1594 [==============================] - 45s 29ms/step - loss: 0.1576 - accuracy: 0.9579 - val_loss: 0.0476 - val_accuracy: 0.9882
# Epoch 10/10
# 1594/1594 [==============================] - 46s 29ms/step - loss: 0.1486 - accuracy: 0.9599 - val_loss: 0.0535 - val_accuracy: 0.9858

# %%
model_20 = models.Sequential()
model_20.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
model_20.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_20.add(Dropout(0.75))
model_20.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform'))
model_20.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_20.add(layers.Flatten())
model_20.add(layers.Dense(64, activation='relu', kernel_initializer='he_uniform'))
model_20.add(layers.Dense(32, activation='relu', kernel_initializer='he_uniform'))
model_20.add(Dropout(0.75))
model_20.add(layers.Dense(10, activation='softmax'))

# %%
opt_3 = optimizers.SGD(learning_rate=0.01, momentum=0.9)
model_20.compile(optimizer=opt_3, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_20.fit(X_train, y_train, epochs=10, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_20)
# Out:
# Epoch 1/10
# 1594/1594 [==============================] - 47s 29ms/step - loss: 2.3043 - accuracy: 0.1149 - val_loss: 2.2811 - val_accuracy: 0.1716
# Epoch 2/10
# 1594/1594 [==============================] - 48s 30ms/step - loss: 2.2290 - accuracy: 0.1383 - val_loss: 2.2240 - val_accuracy: 0.1922
# Epoch 3/10
# 1594/1594 [==============================] - 46s 29ms/step - loss: 2.0927 - accuracy: 0.1863 - val_loss: 1.9394 - val_accuracy: 0.3158
# Epoch 4/10
# 1594/1594 [==============================] - 47s 29ms/step - loss: 1.8381 - accuracy: 0.2929 - val_loss: 1.3976 - val_accuracy: 0.5220
# Epoch 5/10
# 1594/1594 [==============================] - 48s 30ms/step - loss: 1.2208 - accuracy: 0.5590 - val_loss: 0.4406 - val_accuracy: 0.9417
# Epoch 6/10
# 1594/1594 [==============================] - 47s 30ms/step - loss: 0.8849 - accuracy: 0.7009 - val_loss: 0.2831 - val_accuracy: 0.9502
# Epoch 7/10
# 1594/1594 [==============================] - 49s 30ms/step - loss: 0.8076 - accuracy: 0.7374 - val_loss: 0.2538 - val_accuracy: 0.9548
# Epoch 8/10
# 1594/1594 [==============================] - 48s 30ms/step - loss: 0.7754 - accuracy: 0.7515 - val_loss: 0.2300 - val_accuracy: 0.9613
# Epoch 9/10
# 1594/1594 [==============================] - 49s 31ms/step - loss: 0.7491 - accuracy: 0.7598 - val_loss: 0.1822 - val_accuracy: 0.9693
# Epoch 10/10
# 1594/1594 [==============================] - 48s 30ms/step - loss: 0.6871 - accuracy: 0.7804 - val_loss: 0.1619 - val_accuracy: 0.9731

# %%
model_21 = models.Sequential()
model_21.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
model_21.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_21.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform'))
model_21.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_21.add(Dropout(0.75))
model_21.add(layers.Flatten())
model_21.add(layers.Dense(64, activation='relu', kernel_initializer='he_uniform'))
model_21.add(Dropout(0.75))
model_21.add(layers.Dense(32, activation='relu', kernel_initializer='he_uniform'))
model_21.add(Dropout(0.75))
model_21.add(layers.Dense(10, activation='softmax'))

# %%
opt_3 = optimizers.SGD(learning_rate=0.01, momentum=0.9)
model_21.compile(optimizer=opt_3, loss='categorical_crossentropy', metrics=['accuracy'])
history = model_21.fit(X_train, y_train, epochs=10, batch_size=32, shuffle=True,validation_data=(X_val, y_val), verbose=1)
saved_models.append(model_21)
# Out:
# Epoch 1/10
# 1594/1594 [==============================] - 48s 30ms/step - loss: 2.3089 - accuracy: 0.1101 - val_loss: 2.3030 - val_accuracy: 0.1101
# Epoch 2/10
# 1594/1594 [==============================] - 44s 28ms/step - loss: 2.3018 - accuracy: 0.1128 - val_loss: 2.3019 - val_accuracy: 0.1101
# Epoch 3/10
# 1594/1594 [==============================] - 46s 29ms/step - loss: 2.3020 - accuracy: 0.1104 - val_loss: 2.3016 - val_accuracy: 0.1101
# Epoch 4/10
# 1594/1594 [==============================] - 45s 28ms/step - loss: 2.3019 - accuracy: 0.1119 - val_loss: 2.3021 - val_accuracy: 0.1101
# Epoch 5/10
# 1594/1594 [==============================] - 46s 29ms/step - loss: 2.3019 - accuracy: 0.1121 - val_loss: 2.3017 - val_accuracy: 0.1101
# Epoch 6/10
# 1594/1594 [==============================] - 49s 31ms/step - loss: 2.3020 - accuracy: 0.1113 - val_loss: 2.3026 - val_accuracy: 0.1101
# Epoch 7/10
# 1594/1594 [==============================] - 48s 30ms/step - loss: 2.3018 - accuracy: 0.1130 - val_loss: 2.3021 - val_accuracy: 0.1101
# Epoch 8/10
# 1594/1594 [==============================] - 45s 28ms/step - loss: 2.3019 - accuracy: 0.1123 - val_loss: 2.3020 - val_accuracy: 0.1101
# Epoch 9/10
# 1594/1594 [==============================] - 47s 29ms/step - loss: 2.3020 - accuracy: 0.1109 - val_loss: 2.3021 - val_accuracy: 0.1101
# Epoch 10/10
# 1594/1594 [==============================] - 48s 30ms/step - loss: 2.3019 - accuracy: 0.1110 - val_loss: 2.3019 - val_accuracy: 0.1101

# %%
best_model, best_accuracy = evaluate_model(saved_models, X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2819 - accuracy: 0.9213
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2225 - accuracy: 0.9385
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1793 - accuracy: 0.9486
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1258 - accuracy: 0.9830
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0492 - accuracy: 0.9837
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0359 - accuracy: 0.9899
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0375 - accuracy: 0.9920
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1074 - accuracy: 0.9716
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0484 - accuracy: 0.9897
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0564 - accuracy: 0.9861
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0629 - accuracy: 0.9880
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0367 - accuracy: 0.9910
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0379 - accuracy: 0.9893
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0397 - accuracy: 0.9900
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0418 - accuracy: 0.9891
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0817 - accuracy: 0.9840
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4740 - accuracy: 0.9514
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0357 - accuracy: 0.9905
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0386 - accuracy: 0.9880
# 313/313 [==============================] - 3s 8ms/step - loss: 0.1540 - accuracy: 0.9739
# 313/313 [==============================] - 3s 9ms/step - loss: 2.3017 - accuracy: 0.1135
# model: 7 accuracy: 99.20 %

# %% [markdown]
# #Models Evaluation

# %%
from operator import itemgetter
for i in range(0, len(saved_models)):
  loss, acc = saved_models[i].evaluate(X_test, y_test, verbose = 0)
  accuracies.append(acc)
  print('models: ' + str(i + 1), '%.2f'%(acc * 100) + '%')
# Out:
# models: 1 92.13%
# models: 2 93.85%
# models: 3 94.86%
# models: 4 98.30%
# models: 5 98.37%
# models: 6 98.99%
# models: 7 99.20%
# models: 8 97.16%
# models: 9 98.97%
# models: 10 98.61%
# models: 11 98.80%
# models: 12 99.10%
# models: 13 98.93%
# models: 14 99.00%
# models: 15 98.91%
# models: 16 98.40%
# models: 17 95.14%
# models: 18 99.05%
# models: 19 98.80%
# models: 20 97.39%
# models: 21 11.35%

# %%
summaries(saved_models)
# Out:
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
# model: 21
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_33 (Dense)            (None, 64)                51264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,242
# Trainable params: 63,242
# Non-trainable params: 0
# _________________________________________________________________
